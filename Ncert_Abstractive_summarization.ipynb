# %%
import pandas as pd
import nltk

# %%
data=pd.read_excel('//content//data.xlsx')

# %%
data
# Out:
#     CLASS  CHAPTER NUMBER                                         TOPIC NAME  \
# 0     9.0             1.0                                 States of Matter\n
# 1     9.0             1.0                     Can Matter Change its State?\n
# 2     9.0             1.0                                        Evaporation
# 3     9.0             2.0                               What is a Mixture?\n
# 4     9.0             2.0                                What is a Solution?
# 5     9.0             2.0                     Physical and Chemical\nChanges
# 6     9.0             2.0                          Types of Pure\nSubstances
# 7     9.0             3.0                       Laws of Chemical Combination
# 8     9.0             3.0                                   What is an Atom?
# 9     9.0             3.0                                What is a Molecule?
# 10    9.0             3.0                          Writing Chemical Formulae
# ...

# %%
# From here preprocessig next step is done
data['TEXT'] = data['TEXT'].apply(lambda x: x.replace('\n', ' ') if isinstance(x, str) else x)

# %%
text=data['TEXT'][0]

# %%
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
sentence_wise_tokensier= sent_tokenize(text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
sentence_wise_tokensier
# Out:
# ['Observe different types of matter around you.',
#  'What are its different states?',
#  'We can see that matter around us exists in three different states– solid, liquid and gas.',
#  'These states of matter arise due to the variation in the characteristics of the particles of matter.',
#  'Now, let us study about the properties of these three states of matter in detail.',
#  '1.3.1 THE SOLID STATE Activity _____________ 1.9 • Collect the following articles — a pen, a book, a needle and a piece of wooden stick.',
#  '• Sketch the shape of the above articles in your notebook by moving a pencil around them.',
#  '• Do all these have a definite shape, distinct boundaries and a fixed volume?',
#  '• What happens if they are hammered, pulled or dropped?',
#  '• Are these capable of diffusing into each other?',
#  '• Try compressing them by applying force.',
#  'Are you able to compress them?',
#  'All the above are examples of solids.',
# ...

# %%
from nltk.tokenize import word_tokenize
word_wise_tokensise = word_tokenize(text)

# %%
word_wise_tokensise
# Out:
# ['Observe',
#  'different',
#  'types',
#  'of',
#  'matter',
#  'around',
#  'you',
#  '.',
#  'What',
#  'are',
#  'its',
#  'different',
#  'states',
#  '?',
#  'We',
#  'can',
#  'see',
#  'that',
#  'matter',
#  'around',
#  'us',
#  'exists',
#  'in',
#  'three',
#  'different',
#  'states–',
#  'solid',
#  ',',
#  'liquid',
#  'and',
#  'gas',
#  '.',
#  'These',
#  'states',
#  'of',
#  'matter',
#  'arise',
#  'due',
#  'to',
#  'the',
#  'variation',
#  'in',
#  'the',
#  'characteristics',
#  'of',
#  'the',
#  'particles',
#  'of',
#  'matter',
#  '.',
#  'Now',
#  ',',
#  'let',
#  'us',
#  'study',
#  'about',
#  'the',
#  'properties',
#  'of',
#  'these',
#  'three',
#  'states',
#  'of',
#  'matter',
#  'in',
#  'detail',
#  '.',
#  '1.3.1',
#  'THE',
#  'SOLID',
#  'STATE',
#  'Activity',
#  '_____________',
#  '1.9',
#  '•',
#  'Collect',
#  'the',
#  'following',
#  'articles',
#  '—',
#  'a',
#  'pen',
#  ',',
#  'a',
#  'book',
#  ',',
#  'a',
#  'needle',
# ...

# %%
from transformers import T5Tokenizer
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# ...

# %%
tokenise_wrt_t5=tokenizer(text, return_tensors="pt")

# %%
tokenise_wrt_t5
# Out:
# {'input_ids': tensor([[    3, 16018,    15,  ...,  6295,     5,     1]]), 'attention_mask': tensor([[1, 1, 1,  ..., 1, 1, 1]])}

# %%
tokenizer.decode(tokenise_wrt_t5['input_ids'][0], skip_special_tokens=True)
# Out:
# 'Observe different types of matter around you. What are its different states? We can see that matter around us exists in three different states– solid, liquid and gas. These states of matter arise due to the variation in the characteristics of the particles of matter. Now, let us study about the properties of these three states of matter in detail. 1.3.1 THE SOLID STATE Activity _____________ 1.9 • Collect the following articles — a pen, a book, a needle and a piece of wooden stick. • Sketch the shape of the above articles in your notebook by moving a pencil around them. • Do all these have a definite shape, distinct boundaries and a fixed volume? • What happens if they are hammered, pulled or dropped? • Are these capable of diffusing into each other? • Try compressing them by applying force. Are you able to compress them? All the above are examples of solids. We can observe that all these have a definite shape, distinct boundaries and fixed volumes, that is, have negligible compress
# ...

# %%
from transformers import BartTokenizer
tokeniser_wrt_bart=BartTokenizer.from_pretrained('facebook/bart-base')
tokens_wrt_bart=tokeniser_wrt_bart(text, return_tensors="pt")
# Out:
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.72k [00:00<?, ?B/s]

# %%
tokens_wrt_bart
# Out:
# {'input_ids': tensor([[    0, 40089, 14477,  ...,     4,  1437,     2]]), 'attention_mask': tensor([[1, 1, 1,  ..., 1, 1, 1]])}

# %%
decoded_text = tokeniser_wrt_bart.decode(tokens_wrt_bart['input_ids'][0], skip_special_tokens=True)
decoded_text
# Out:
# 'Observe different types of matter around you. What are its different states? We can see that matter around us exists in three different states– solid, liquid and gas. These states of matter arise due to the variation in the characteristics of the particles of matter. Now, let us study about the properties of these three states of matter in detail. 1.3.1 THE SOLID STATE Activity _____________ 1.9 • Collect the following articles — a pen, a book, a needle and a piece of wooden stick. • Sketch the shape of the above articles in your notebook by moving a pencil around them. • Do all these have a definite shape, distinct boundaries and a fixed volume? • What happens if they are hammered, pulled or dropped? • Are these capable of diffusing into each other? • Try compressing them by applying force. Are you able to compress them? All the above are examples of solids. We can observe that all these have a definite shape, distinct boundaries and fixed volumes, that is, have negligible compress
# ...

# %%
from transformers import PegasusTokenizer
pegasus_tokenizer = PegasusTokenizer.from_pretrained('google/pegasus-xsum')
tokenized_pegasus_text = pegasus_tokenizer(text, return_tensors="pt")
tokenized_pegasus_text
# Out:
# tokenizer_config.json:   0%|          | 0.00/87.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.52M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1141 > 512). Running this sequence through the model will result in indexing errors
# {'input_ids': tensor([[56729,   291,  1020,  ...,  4043,   107,     1]]), 'attention_mask': tensor([[1, 1, 1,  ..., 1, 1, 1]])}

# %%
decoded_pegasus_text = pegasus_tokenizer.decode(tokenized_pegasus_text['input_ids'][0], skip_special_tokens=True)
decoded_pegasus_text
# Out:
# 'Observe different types of matter around you. What are its different states? We can see that matter around us exists in three different states– solid, liquid and gas. These states of matter arise due to the variation in the characteristics of the particles of matter. Now, let us study about the properties of these three states of matter in detail. 1.3.1 THE SOLID STATE Activity _____________ 1.9 • Collect the following articles — a pen, a book, a needle and a piece of wooden stick. • Sketch the shape of the above articles in your notebook by moving a pencil around them. • Do all these have a definite shape, distinct boundaries and a fixed volume? • What happens if they are hammered, pulled or dropped? • Are these capable of diffusing into each other? • Try compressing them by applying force. Are you able to compress them? All the above are examples of solids. We can observe that all these have a definite shape, distinct boundaries and fixed volumes, that is, have negligible compress
# ...

# %%
from transformers import GPT2Tokenizer
tokenizer_gpt = GPT2Tokenizer.from_pretrained('gpt2')
tokensised_wrt_gpt=tokenizer_gpt(text, return_tensors="pt",truncation=True, max_length=512)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]

# %%
tokensised_wrt_gpt
# Out:
# {'input_ids': tensor([[31310,  3760,  1180,  3858,   286,  2300,  1088,   345,    13,  1867,
#            389,   663,  1180,  2585,    30,   775,   460,   766,   326,  2300,
#           1088,   514,  7160,   287,  1115,  1180,  2585,  1906,  4735,    11,
#           8122,   290,  3623,    13,  2312,  2585,   286,  2300, 15058,  2233,
#            284,   262, 12291,   287,   262,  9695,   286,   262, 13166,   286,
#           2300,    13,  2735,    11,  1309,   514,  2050,   546,   262,  6608,
#            286,   777,  1115,  2585,   286,  2300,   287,  3703,    13,   352,
#             13,    18,    13,    16,  3336, 36817,  2389, 35454, 24641,   220,
#           2602, 29343,   352,    13,    24,  5595,  9745,   262,  1708,  6685,
#            851,   257,  3112,    11,   257,  1492,    11,   257, 17598,   290,
#            257,  3704,   286, 13510,  4859,    13,  5595, 17001,   262,  5485,
#            286,   262,  2029,  6685,   287,   534, 20922,   416,  3867,   257,
# ...

# %%
decoded_text_gpt=tokenizer_gpt.decode(tokensised_wrt_gpt['input_ids'][0], skip_special_tokens=True)
decoded_text_gpt
# Out:
# 'Observe different types of matter around you. What are its different states? We can see that matter around us exists in three different states– solid, liquid and gas. These states of matter arise due to the variation in the characteristics of the particles of matter. Now, let us study about the properties of these three states of matter in detail. 1.3.1 THE SOLID STATE Activity _____________ 1.9 • Collect the following articles — a pen, a book, a needle and a piece of wooden stick. • Sketch the shape of the above articles in your notebook by moving a pencil around them. • Do all these have a definite shape, distinct boundaries and a fixed volume? • What happens if they are hammered, pulled or dropped? • Are these capable of diffusing into each other? • Try compressing them by applying force. Are you able to compress them? All the above are examples of solids. We can observe that all these have a definite shape, distinct boundaries and fixed volumes, that is, have negligible compress
# ...

# %%
# !pip install transformers datasets pandas torch openpyxl
# !pip install --upgrade accelerate
# !pip install --upgrade transformers[torch]

import pandas as pd
from datasets import Dataset, DatasetDict
from transformers import T5ForConditionalGeneration, T5Tokenizer, Trainer, TrainingArguments

# Load and preprocess data from Excel
data = pd.read_excel('data.xlsx')  # Path to your Excel file

# Ensure text column is named 'text' for consistency
data = data.rename(columns={'TEXT': 'text'})  # Replace 'TEXT' with your actual column name

# Drop rows where 'text' is None or empty
data = data.dropna(subset=['text']).reset_index(drop=True)
data['text'] = data['text'].apply(lambda x: x if isinstance(x, str) else "")

# Convert to Hugging Face Dataset
dataset = Dataset.from_pandas(data)

# Define the model and tokenizer
model_name = "t5-small"  # You can choose other models like 't5-base', 'facebook/bart-base', etc.
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)

# Tokenize data
def preprocess_function(examples):
    inputs = ["summarize: " + (doc if doc is not None else "") for doc in examples["text"]]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer([doc if doc is not None else "" for doc in examples["text"]],
                           max_length=150, truncation=True, padding="max_length")

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Tokenize and preprocess data
tokenized_datasets = dataset.map(preprocess_function, batched=True)

# Split dataset into training and evaluation in 90:10 ratio
split_ratio = 0.1
dataset_dict = tokenized_datasets.train_test_split(test_size=split_ratio)

train_dataset = dataset_dict["train"]
eval_dataset = dataset_dict["test"]

# Set up training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='./logs',  # Log directory
    logging_steps=10,
    save_total_limit=2,
    save_steps=10,
)

# Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
)

# Train the model
trainer.train()

# Generate summaries (you can keep your summarize function as is)
def summarize(texts):
    inputs = tokenizer(["summarize: " + text for text in texts], return_tensors="pt", padding=True, truncation=True, max_length=512)
    outputs = model.generate(
        inputs["input_ids"],
        max_length=150,
        min_length=40,
        length_penalty=2.0,
        num_beams=4,
        early_stopping=True
    )
    return [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
# Print summaries
texts = data['text'].tolist()
summaries = summarize(texts)

for i, summary in enumerate(summaries):
    print(f"Original: {texts[i]}")
    print(f"Summary: {summary}\n")
# Out:
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
#here due to lack of computaional resource i am able to get only loss value and not its output---gpt2 model(heavy model)
# !pip install transformers datasets pandas torch openpyxl
# !pip install --upgrade accelerate

import pandas as pd
from datasets import Dataset, DatasetDict
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments, DataCollatorForLanguageModeling

# Load and preprocess data from Excel
data = pd.read_excel('data.xlsx')  # Path to your Excel file

# Ensure text column is named 'text' for consistency
data = data.rename(columns={'TEXT': 'text'})  # Replace 'TEXT' with your actual column name

# Drop rows where 'text' is None or empty
data = data.dropna(subset=['text']).reset_index(drop=True)
data['text'] = data['text'].apply(lambda x: x if isinstance(x, str) else "")

# Convert to Hugging Face Dataset
dataset = Dataset.from_pandas(data)

# Define the model and tokenizer
model_name = "gpt2"  # You can choose other models like 'gpt2-medium', 'gpt2-large', etc.
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token  # Set pad token to eos token for compatibility
tokenizer.padding_side = "left"  # Set padding side to left

# Tokenize data
def preprocess_function(examples):
    inputs = examples["text"]
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")
    return model_inputs

# Tokenize and preprocess data
tokenized_datasets = dataset.map(preprocess_function, batched=True)

# Split dataset into training and evaluation in 90:10 ratio
split_ratio = 0.1
dataset_dict = tokenized_datasets.train_test_split(test_size=split_ratio)

train_dataset = dataset_dict["train"]
eval_dataset = dataset_dict["test"]

# Data collator for language modeling
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False,  # GPT models do not use masked language modeling
)

# Set up training arguments
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",  # Updated from evaluation_strategy
    learning_rate=5e-5,
    per_device_train_batch_size=2,  # GPT models might require smaller batch sizes due to higher memory usage
    per_device_eval_batch_size=2,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='./logs',  # Log directory
    logging_steps=10,
    save_total_limit=1,  # Save fewer checkpoints
    save_steps=50,       # Save checkpoints less frequently
    save_safetensors=False,  # Disable safe serialization
)

# Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    data_collator=data_collator,
)

# Train the model
trainer.train()

# Generate text
def generate_text(prompts):
    inputs = tokenizer(prompts, return_tensors="pt", padding=True, truncation=True, max_length=512)
    outputs = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],  # Set attention_mask for reliable results
        max_new_tokens=150,  # Use max_new_tokens instead of max_length
        num_return_sequences=1,
        no_repeat_ngram_size=2,
        num_beams=5,
        temperature=1.0,
        top_p=0.95,
        top_k=50,
        early_stopping=True,
        do_sample=True  # Ensure sampling is used since top_p is set
    )
    return [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]

# Print generated texts
texts = data['text'].tolist()
generated_texts = generate_text(texts)

for i, generated in enumerate(generated_texts):
    print(f"Original: {texts[i]}")
    print(f"Generated: {generated}\n")
# Out:
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -ransformers (/usr/local/lib/python3.10/dist-packages)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
#     <div>
#
# ...

# %%
#pegasus usage --great but computational cost but can be better used susing small batches and great dfine tuning
#and needs approx 17 gb ram we didnt have it and we tried more constraints
# !pip install transformers datasets pandas torch openpyxl
# !pip install --upgrade accelerate
# !pip install --upgrade transformers[torch]

import pandas as pd
import torch
from datasets import Dataset, DatasetDict
from transformers import PegasusForConditionalGeneration, PegasusTokenizer, Trainer, TrainingArguments

# Load and preprocess data from Excel
data = pd.read_excel('data.xlsx')  # Ensure correct path to your Excel file

# Ensure text column is named 'text' for consistency
data = data.rename(columns={'TEXT': 'text'})  # Replace 'TEXT' with your actual column name

# Drop rows where 'text' is None or empty
data = data.dropna(subset=['text']).reset_index(drop=True)
data['text'] = data['text'].apply(lambda x: x if isinstance(x, str) else "")

# Convert to Hugging Face Dataset
dataset = Dataset.from_pandas(data)

# Define the model and tokenizer
model_name = "google/pegasus-xsum"  # Use a smaller Pegasus model variant
model = PegasusForConditionalGeneration.from_pretrained(model_name)
tokenizer = PegasusTokenizer.from_pretrained(model_name)

# Tokenize data
def preprocess_function(examples):
    inputs = ["summarize: " + (doc if doc is not None else "") for doc in examples["text"]]
    model_inputs = tokenizer(inputs, max_length=128, truncation=True, padding="max_length")  # Reduced max_length

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer([doc if doc is not None else "" for doc in examples["text"]],
                           max_length=80, truncation=True, padding="max_length")  # Reduced max_length

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Tokenize and preprocess data
tokenized_datasets = dataset.map(preprocess_function, batched=True)

# Split dataset into training and evaluation in 90:10 ratio
split_ratio = 0.1
dataset_dict = tokenized_datasets.train_test_split(test_size=split_ratio)

train_dataset = dataset_dict["train"]
eval_dataset = dataset_dict["test"]

# Clear CUDA cache to free up memory
torch.cuda.empty_cache()

# Set up training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=1,  # Reduced batch size
    per_device_eval_batch_size=1,   # Reduced batch size
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='./logs',  # Log directory
    logging_steps=10,
    save_total_limit=2,
    save_steps=10,
    gradient_accumulation_steps=32,  # Increased gradient accumulation steps
    fp16=True,  # Mixed precision training
    gradient_checkpointing=True,  # Enable gradient checkpointing
)

# Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
)

# Train the model
trainer.train()

# Generate summaries
def summarize(texts):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    inputs = tokenizer(["summarize: " + text for text in texts], return_tensors="pt", padding=True, truncation=True, max_length=128).to(device)  # Reduced max_length
    outputs = model.generate(
        inputs["input_ids"],
        max_length=80,
        min_length=30,
        length_penalty=2.0,
        num_beams=4,
        early_stopping=True
    )
    return [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]

# Print summaries
texts = data['text'].tolist()
summaries = summarize(texts)

for i, summary in enumerate(summaries):
    print(f"Original: {texts[i]}")
    print(f"Summary: {summary}\n")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
# BART-For highly abstractive version you can go on with BART(facebook/bart-large-xsum version)
#and if you have less computational capability it takes less than 10gb ram and it runs great and with
#second best accuracy and it has only 0.15% less accuracy than pegasus but gives lot of computational freedom
# !pip install transformers datasets pandas torch openpyxl
# !pip install --upgrade accelerate
# !pip install --upgrade transformers[torch]

import pandas as pd
import torch
from datasets import Dataset
from transformers import BartForConditionalGeneration, BartTokenizer, Trainer, TrainingArguments

# Load and preprocess data from Excel
data = pd.read_excel('data.xlsx')  # Ensure correct path to your Excel file

# Ensure text column is named 'text' for consistency
data = data.rename(columns={'TEXT': 'text'})  # Replace 'TEXT' with your actual column name

# Drop rows where 'text' is None or empty
data = data.dropna(subset=['text']).reset_index(drop=True)
data['text'] = data['text'].apply(lambda x: x if isinstance(x, str) else "")

# Convert to Hugging Face Dataset
dataset = Dataset.from_pandas(data)

# Define the model and tokenizer
model_name = "facebook/bart-large-xsum"  # BART model for abstractive summarization
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Tokenize data
def preprocess_function(examples):
    inputs = ["summarize: " + (doc if doc is not None else "") for doc in examples["text"]]
    model_inputs = tokenizer(inputs, max_length=128, truncation=True, padding="max_length")  # Reduced max_length

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer([doc if doc is not None else "" for doc in examples["text"]],
                           max_length=80, truncation=True, padding="max_length")  # Reduced max_length

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Tokenize and preprocess data
tokenized_datasets = dataset.map(preprocess_function, batched=True)

# Split dataset into training and evaluation in 90:10 ratio
split_ratio = 0.1
dataset_dict = tokenized_datasets.train_test_split(test_size=split_ratio)

train_dataset = dataset_dict["train"]
eval_dataset = dataset_dict["test"]

# Clear CUDA cache to free up memory
torch.cuda.empty_cache()

# Set up training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=1,  # Reduced batch size
    per_device_eval_batch_size=1,   # Reduced batch size
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir='./logs',  # Log directory
    logging_steps=10,
    save_total_limit=2,
    save_steps=10,
    gradient_accumulation_steps=32,  # Increased gradient accumulation steps
    fp16=True,  # Mixed precision training
    gradient_checkpointing=True,  # Enable gradient checkpointing
)

# Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
)

# Train the model
trainer.train()

# Generate summaries
def summarize(texts):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    inputs = tokenizer(["summarize: " + text for text in texts], return_tensors="pt", padding=True, truncation=True, max_length=128).to(device)  # Reduced max_length
    outputs = model.generate(
        inputs["input_ids"],
        max_length=80,
        min_length=30,
        length_penalty=2.0,
        num_beams=4,
        early_stopping=True
    )
    return [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]

# Print summaries
texts = data['text'].tolist()
summaries = summarize(texts)

for i, summary in enumerate(summaries):
    print(f"Original: {texts[i]}")
    print(f"Summary: {summary}\n")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
